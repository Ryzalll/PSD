# %% [markdown]
# # Deteksi Outlier

# %% [markdown]
# ## Koneksi ke dataset

# %%
# %run connection.ipynb
# Out:
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_10488\1024078359.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   my_df_mysql = pd.read_sql(query, conn)
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_10488\1024078359.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pg_df = pd.read_sql(query, conn)

# %%
info = df.info()

# Struktur data (kolom, tipe data, jumlah missing values)
structure = {
    "shape": df.shape,
    "columns": df.dtypes.to_dict(),
    "missing_values": df.isnull().sum().to_dict()
}

# Statistik deskriptif
desc_stats = df.describe(include="all")

# Distribusi kolom numerik
distribution = df.hist(figsize=(10, 8))

import matplotlib.pyplot as plt
plt.tight_layout()
plt.close()  # prevent double plot rendering

structure, desc_stats.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            150 non-null    int64
#  1   species       150 non-null    object
#  2   sepal_length  150 non-null    float64
#  3   sepal_width   150 non-null    float64
#  4   petal_length  150 non-null    float64
#  5   petal_width   150 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# ({'shape': (150, 6),
#   'columns': {'id': dtype('int64'),
#    'species': dtype('O'),
#    'sepal_length': dtype('float64'),
#    'sepal_width': dtype('float64'),
#    'petal_length': dtype('float64'),
#    'petal_width': dtype('float64')},
#   'missing_values': {'id': 0,
#    'species': 0,
#    'sepal_length': 0,
#    'sepal_width': 0,
#    'petal_length': 0,
#    'petal_width': 0}},
#             id      species  sepal_length  sepal_width  petal_length  \
#  count   150.0          150    150.000000      150.000    150.000000
#  unique    NaN            3           NaN          NaN           NaN
#  top       NaN  Iris-setosa           NaN          NaN           NaN
#  freq      NaN           50           NaN          NaN           NaN
#  mean     75.5          NaN      5.843333        3.054      3.758667
#
#          petal_width
#  count    150.000000
#  unique          NaN
#  top             NaN
#  freq            NaN
#  mean       1.198667  )

# %% [markdown]
# ## Load Model

# %% [markdown]
# ### ABOD (Angel Based Outlier Detection)

# %%
from pycaret.anomaly import *

exp_name = setup(data = df)
abod = create_model('abod')
# Out:
# <style type="text/css">
# #T_619f9_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_619f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_619f9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_619f9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_619f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_619f9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_619f9_row0_col1" class="data row0 col1" >8029</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_619f9_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_619f9_row1_col1" class="data row1 col1" >(150, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_619f9_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_619f9_row2_col1" class="data row2 col1" >(150, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_619f9_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_619f9_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_619f9_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_619f9_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_619f9_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_619f9_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_619f9_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_619f9_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_619f9_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_619f9_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_619f9_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_619f9_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_619f9_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_619f9_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_619f9_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_619f9_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_619f9_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_619f9_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_619f9_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_619f9_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_619f9_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_619f9_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_619f9_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_619f9_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_619f9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_619f9_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_619f9_row15_col1" class="data row15 col1" >10a8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### LOF (Local Outlier Factor)

# %%
exp_name = setup(data = df)
lof = create_model('lof')
# Out:
# <style type="text/css">
# #T_e8d78_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8d78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8d78_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8d78_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8d78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8d78_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e8d78_row0_col1" class="data row0 col1" >6425</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8d78_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e8d78_row1_col1" class="data row1 col1" >(150, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8d78_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_e8d78_row2_col1" class="data row2 col1" >(150, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8d78_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_e8d78_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8d78_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_e8d78_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8d78_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_e8d78_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8d78_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_e8d78_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8d78_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_e8d78_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8d78_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_e8d78_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8d78_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_e8d78_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e8d78_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_e8d78_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e8d78_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_e8d78_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e8d78_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_e8d78_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e8d78_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_e8d78_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e8d78_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_e8d78_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e8d78_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e8d78_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_e8d78_row15_col1" class="data row15 col1" >d2da</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### KNN (k-Nearest Neighbors Detector)

# %%
exp_name = setup(data = df)
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_532b5_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_532b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_532b5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_532b5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_532b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_532b5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_532b5_row0_col1" class="data row0 col1" >3264</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_532b5_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_532b5_row1_col1" class="data row1 col1" >(150, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_532b5_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_532b5_row2_col1" class="data row2 col1" >(150, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_532b5_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_532b5_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_532b5_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_532b5_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_532b5_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_532b5_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_532b5_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_532b5_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_532b5_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_532b5_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_532b5_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_532b5_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_532b5_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_532b5_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_532b5_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_532b5_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_532b5_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_532b5_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_532b5_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_532b5_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_532b5_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_532b5_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_532b5_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_532b5_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_532b5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_532b5_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_532b5_row15_col1" class="data row15 col1" >8f87</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Implementasi Model ke dataset

# %%
# Assign model -> hasilkan dataframe dengan kolom anomaly
df_anomaly_abod = assign_model(abod)
df_anomaly_lof = assign_model(lof)
df_anomaly_knn = assign_model(knn)

# %% [markdown]
# ## Menampilkan Data dengan skor outlier tertinggi

# %%
df_sorted_abod = df_anomaly_abod.sort_values(by="Anomaly_Score", ascending=False).reset_index(drop=True)
print('Top 5 Deteksi Anomali berdasarkan (ABOD)')
df_sorted_abod.head()
# Out:
# Top 5 Deteksi Anomali berdasarkan (ABOD)
#     id         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  107  Iris-virginica           4.9          2.5           4.5          1.7
# 1  123  Iris-virginica           7.7          2.8           6.7          2.0
# 2  119  Iris-virginica           7.7          2.6           6.9          2.3
# 3  118  Iris-virginica           7.7          3.8           6.7          2.2
# 4  120  Iris-virginica           6.0          2.2           5.0          1.5
#
#    Anomaly  Anomaly_Score
# 0        1      -0.001276
# 1        1      -0.004978
# 2        1      -0.005204
# 3        1      -0.005361
# 4        1      -0.006080

# %%
df_sorted_lof = df_anomaly_lof.sort_values(by="Anomaly_Score", ascending=False).reset_index(drop=True)
print('Top 5 Deteksi Anomali berdasarkan (LOF)')
df_sorted_lof.head()
# Out:
# Top 5 Deteksi Anomali berdasarkan (LOF)
#     id         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0    1     Iris-setosa           5.1          3.5           1.4          0.2
# 1  150  Iris-virginica           5.9          3.0           5.1          1.8
# 2    2     Iris-setosa           4.9          3.0           1.4          0.2
# 3  149  Iris-virginica           6.2          3.4           5.4          2.3
# 4    3     Iris-setosa           4.7          3.2           1.3          0.2
#
#    Anomaly  Anomaly_Score
# 0        1       1.256153
# 1        1       1.253521
# 2        1       1.217657
# 3        1       1.214298
# 4        1       1.183005

# %%
df_sorted_knn = df_anomaly_knn.sort_values(by="Anomaly_Score", ascending=False).reset_index(drop=True)
print('Top 5 Deteksi Anomali berdasarkan (KNN)')
df_sorted_knn.head()
# Out:
# Top 5 Deteksi Anomali berdasarkan (KNN)
#     id          species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  150   Iris-virginica           5.9          3.0           5.1          1.8
# 1    1      Iris-setosa           5.1          3.5           1.4          0.2
# 2   51  Iris-versicolor           7.0          3.2           4.7          1.4
# 3   50      Iris-setosa           5.0          3.3           1.4          0.2
# 4    2      Iris-setosa           4.9          3.0           1.4          0.2
#
#    Anomaly  Anomaly_Score
# 0        1       5.155579
# 1        1       5.037857
# 2        1       4.397727
# 3        1       4.389761
# 4        1       4.146083

# %% [markdown]
# ## Menghapus Data dengan 2 skor outlier tertinggi

# %%
df_abod_clean = df_sorted_abod.iloc[2:].reset_index(drop=True)
df_abod_clean = df_abod_clean.sort_values(by="id").reset_index(drop=True)
df_abod_clean.head()
# Out:
#    id      species  sepal_length  sepal_width  petal_length  petal_width  \
# 0   1  Iris-setosa           5.1          3.5           1.4          0.2
# 1   2  Iris-setosa           4.9          3.0           1.4          0.2
# 2   3  Iris-setosa           4.7          3.2           1.3          0.2
# 3   4  Iris-setosa           4.6          3.1           1.5          0.2
# 4   5  Iris-setosa           5.0          3.6           1.4          0.2
#
#    Anomaly  Anomaly_Score
# 0        0      -0.010918
# 1        0      -0.105879
# 2        0      -0.160850
# 3        0      -0.108965
# 4        0      -0.103372

# %%
df_lof_clean = df_sorted_lof.iloc[2:].reset_index(drop=True)
df_lof_clean = df_lof_clean.sort_values(by="id").reset_index(drop=True)
df_lof_clean.head()
# Out:
#    id      species  sepal_length  sepal_width  petal_length  petal_width  \
# 0   2  Iris-setosa           4.9          3.0           1.4          0.2
# 1   3  Iris-setosa           4.7          3.2           1.3          0.2
# 2   4  Iris-setosa           4.6          3.1           1.5          0.2
# 3   5  Iris-setosa           5.0          3.6           1.4          0.2
# 4   6  Iris-setosa           5.4          3.9           1.7          0.4
#
#    Anomaly  Anomaly_Score
# 0        1       1.217657
# 1        1       1.183005
# 2        1       1.153191
# 3        0       1.126259
# 4        0       1.104792

# %%
df_knn_clean = df_sorted_knn.iloc[2:].reset_index(drop=True)
df_knn_clean = df_knn_clean.sort_values(by="id").reset_index(drop=True)
df_knn_clean.head()
# Out:
#    id      species  sepal_length  sepal_width  petal_length  petal_width  \
# 0   2  Iris-setosa           4.9          3.0           1.4          0.2
# 1   3  Iris-setosa           4.7          3.2           1.3          0.2
# 2   4  Iris-setosa           4.6          3.1           1.5          0.2
# 3   5  Iris-setosa           5.0          3.6           1.4          0.2
# 4   6  Iris-setosa           5.4          3.9           1.7          0.4
#
#    Anomaly  Anomaly_Score
# 0        1       4.146083
# 1        0       3.190611
# 2        0       3.018278
# 3        0       3.008322
# 4        0       3.190611

# %%
print('Ukuran dataset clean dari metode ABOD:', df_abod_clean.shape)
print('Ukuran dataset clean dari metode LOF:', df_lof_clean.shape)
print('Ukuran dataset clean dari metode KNN:', df_knn_clean.shape)
# Out:
# Ukuran dataset clean dari metode ABOD: (148, 8)
# Ukuran dataset clean dari metode LOF: (148, 8)
# Ukuran dataset clean dari metode KNN: (148, 8)

# %% [markdown]
# Hasil diatas menunjukkan bahwa sudah 2 data yang terhapus
