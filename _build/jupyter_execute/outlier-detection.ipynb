# %% [markdown]
# # outlier-detection

# %%
import pandas as pd
import sys
print(sys.version)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
from pycaret.anomaly import *
df = pd.read_csv('../../Dataset/iris-full.csv')

exp_name = setup(data = df)
abod = create_model('abod')
plot_model(abod, plot = 'tsne')
# Out:
# <style type="text/css">
# #T_22fba_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22fba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22fba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22fba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22fba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22fba_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_22fba_row0_col1" class="data row0 col1" >3519</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22fba_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_22fba_row1_col1" class="data row1 col1" >(150, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22fba_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_22fba_row2_col1" class="data row2 col1" >(150, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22fba_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_22fba_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22fba_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_22fba_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22fba_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_22fba_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22fba_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_22fba_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22fba_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_22fba_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22fba_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_22fba_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22fba_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_22fba_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_22fba_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_22fba_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_22fba_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_22fba_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_22fba_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_22fba_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_22fba_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_22fba_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_22fba_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_22fba_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_22fba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_22fba_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_22fba_row15_col1" class="data row15 col1" >9472</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Implementasi Model ke dataset

# %%
# Assign model -> hasilkan dataframe dengan kolom anomaly
df_anomaly = assign_model(abod)

# %% [markdown]
# ## Menampilkan Data dengan skor outlier tertinggi

# %%
df_sorted = df_anomaly.sort_values(by="Anomaly_Score", ascending=False).reset_index(drop=True)
df_sorted.head()
# Out:
#     id           Class  sepal length  sepal width  petal length  petal width  \
# 0  107  Iris-virginica           4.9          2.5           4.5          1.7
# 1  123  Iris-virginica           7.7          2.8           6.7          2.0
# 2  119  Iris-virginica           7.7          2.6           6.9          2.3
# 3  118  Iris-virginica           7.7          3.8           6.7          2.2
# 4  120  Iris-virginica           6.0          2.2           5.0          1.5
#
#    Anomaly  Anomaly_Score
# 0        1      -0.001276
# 1        1      -0.004978
# 2        1      -0.005204
# 3        1      -0.005361
# 4        1      -0.006080

# %% [markdown]
# ## Menghapus Data dengan 2 skor outlier tertinggi

# %%
df_removed = df_sorted.iloc[2:].reset_index(drop=True)
dataset = df_removed.sort_values(by="id").reset_index(drop=True)
dataset.head()
# Out:
#    id        Class  sepal length  sepal width  petal length  petal width  \
# 0   1  Iris-setosa           5.1          3.5           1.4          0.2
# 1   2  Iris-setosa           4.9          3.0           1.4          0.2
# 2   3  Iris-setosa           4.7          3.2           1.3          0.2
# 3   4  Iris-setosa           4.6          3.1           1.5          0.2
# 4   5  Iris-setosa           5.0          3.6           1.4          0.2
#
#    Anomaly  Anomaly_Score
# 0        0      -0.010918
# 1        0      -0.105879
# 2        0      -0.160850
# 3        0      -0.108965
# 4        0      -0.103372

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             148 non-null    int32
#  1   Class          148 non-null    category
#  2   sepal length   148 non-null    float32
#  3   sepal width    148 non-null    float32
#  4   petal length   148 non-null    float32
#  5   petal width    148 non-null    float32
#  6   Anomaly        148 non-null    int32
#  7   Anomaly_Score  148 non-null    float64
# dtypes: category(1), float32(4), float64(1), int32(2)
# memory usage: 5.0 KB
